# %% [markdown]
# # Lista de Exercícios — Laços de Repetição (Python)
# Disciplina: Algoritmos / Estruturas de Dados
#
# Objetivo: praticar estruturas de repetição (`for` e `while`).
#
# Os exercícios estão divididos em três níveis:
# - 🟢 Básico
# - 🟡 Intermediário
# - 🔴 Avançado
#
# Resolva cada exercício no espaço abaixo de cada enunciado.

# %% [markdown]
# ---
# ## 🟢 Nível Básico

# %% [markdown]
# ### 1) Contagem simples
# Imprima os números de **1 até 10** usando um laço.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 2) Contagem regressiva
# Imprima os números de **10 até 1** e depois mostre `Fim!`.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 3) Soma de 1 até 10
# Calcule a soma de todos os números de **1 até 10**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 4) Tabuada
# Peça um número ao usuário e mostre sua tabuada de **1 a 10**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 5) Números pares
# Imprima todos os **números pares entre 1 e 20**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 6) Números ímpares
# Imprima todos os **números ímpares entre 1 e 20**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 7) Contagem até N
# Peça um número **N** e imprima os números de **1 até N**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 8) Soma até N
# Peça um número **N** e calcule a soma de **1 até N**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 9) Validação de senha
# Peça ao usuário uma senha até que ele digite **1234**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 10) Ler 5 números
# Peça **5 números** ao usuário e conte quantos foram digitados.

# %%
# escreva seu código aqui

# %% [markdown]
# ---
# ## 🟡 Nível Intermediário

# %% [markdown]
# ### 11) Maior número
# Peça **5 números** ao usuário e mostre o **maior número**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 12) Média de números
# Peça **5 números** e calcule a **média**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 13) Contar pares
# Peça **10 números** e informe quantos são **pares**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 14) Menu simples
# Crie um menu que repita até o usuário escolher **0 (sair)**.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 15) Soma até zero
# Peça números ao usuário até ele digitar **0**.
# Mostre a soma final.

# %%
# escreva seu código aqui

# %% [markdown]
# ---
# ## 🔴 Nível Avançado

# %% [markdown]
# ### 16) Contagem de positivos e negativos
# Peça **10 números** e informe quantos são positivos, negativos e zero.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 17) Busca de número
# Peça **10 números**.
# Depois peça um número X e informe se ele apareceu.

# %%
# escreva seu código aqui

# %% [markdown]
# ### 18) Caixa eletrônico
# Peça um valor de saque e informe quantas notas serão usadas (100, 50, 20, 10, 5, 1).

# %%
# escreva seu código aqui

# %% [markdown]
# ### 19) Padrão de estrelas
# Imprima o padrão:
#
# ```
# *
# **
# ***
# ****
# *****
# ```

# %%
# escreva seu código aqui

# %% [markdown]
# ### 20) Jogo de adivinhação
# O computador escolhe um número entre **1 e 100**.
# O usuário tenta adivinhar.
# Informe se é maior ou menor até acertar.

# %%
# escreva seu código aqui
