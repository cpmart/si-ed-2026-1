# %% [markdown]
# # Lista de Exercícios — Listas em Python
#
# Material preparado para alunos do **2º semestre**, com foco em reforçar os fundamentos de **listas em Python** e preparar a base para **Estrutura de Dados**.
#
# >Orientações
#
# - Leia cada exercício com atenção.
# - Resolva um exercício por vez.
# - Teste seu código com diferentes valores.
# - Sempre que possível, exiba resultados de forma organizada com `print()`.

# %% [markdown]
# ## Exercício
#
# Crie uma lista com **5 números inteiros** e exiba todos os elementos usando `for`.

# %% [markdown]
# ## Exercício
#
# Peça ao usuário **5 números** e armazene em uma lista. Depois, mostre a lista completa.

# %% [markdown]
# ## Exercício
#
# Dada a lista:
#
# ```python
# [10, 20, 30, 40, 50]
# ```
#
# Exiba:
#
# - o **primeiro elemento**
# - o **último elemento**

# %% [markdown]
# ## Exercício
#
# Peça ao usuário **5 números**, armazene em uma lista e mostre a **soma dos elementos**.

# %% [markdown]
# ## Exercício
#
# Dada a lista:
#
# ```python
# [1, 2, 3, 4, 5]
# ```
#
# Crie outra lista com o **dobro de cada valor**.

# %% [markdown]
# ## Exercício
#
# Crie uma lista com **10 números** e mostre apenas os **números pares**.

# %% [markdown]
# ## Exercício
#
# Peça **6 nomes** ao usuário e armazene em uma lista. Depois, exiba todos os nomes.

# %% [markdown]
# ## Exercício
#
# Dada a lista:
#
# ```python
# [5, 8, 2, 10, 3]
# ```
#
# Encontre:
#
# - o **maior valor**
# - o **menor valor**
#
# > Tente resolver primeiro **sem usar** `max()` e `min()`.

# %% [markdown]
# ## Exercício
#
# Peça **8 números** ao usuário e conte quantos são **maiores que 10**.

# %% [markdown]
# ## Exercício
#
# Dada a lista:
#
# ```python
# [1, 2, 3, 4, 5]
# ```
#
# Crie outra lista com os valores em **ordem inversa**.

# %% [markdown]
# ## Exercício
#
# Peça **5 números**, armazene em uma lista e crie outra lista apenas com os **números ímpares**.

# %% [markdown]
# ## Exercício
#
# Dada a lista:
#
# ```python
# [10, 20, 30, 40, 50]
# ```
#
# Peça um número ao usuário e verifique se ele **está na lista**.

# %% [markdown]
# ## Exercício
#
# Crie uma lista `A` com **5 números**.
#
# Depois faça:
#
# ```python
# B = A
# ```
#
# Altere um valor em `A` e mostre as duas listas.
#
# Em seguida:
#
# - faça uma **cópia correta** de `A`
# - repita o teste
# - explique o que aconteceu

# %% [markdown]
# ## Exercício
#
# Dada a lista:
#
# ```python
# lista = [1, 2, 3, 4, 5, 6, 7, 8]
# ```
#
# Crie:
#
# - uma lista com os **3 primeiros elementos**
# - uma lista com os **3 últimos elementos**
# - uma lista com os **elementos do meio**

# %% [markdown]
# ## Exercício
#
# Peça **10 números** ao usuário.
#
# Depois, crie uma nova lista com apenas os **valores únicos**, ou seja, **sem repetição**.
#
# ### Exemplo
# ```python
# Entrada: [1, 2, 2, 3, 4, 4]
# Saída:   [1, 2, 3, 4]
# ```
