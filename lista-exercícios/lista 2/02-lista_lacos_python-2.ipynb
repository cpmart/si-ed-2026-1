# %% [markdown]
# \section*{Lista de Exercícios — Laços de Repetição em Python}

# %% [markdown]
# **Regras**
#
# - Use apenas `for` ou `while`
# - Não utilize `def`
# - Pode usar `if` dentro dos laços
# - Utilize `print()` para exibir resultados

# %% [markdown]
# # Contagem de 2 em 2
# Imprima os números de 2 até 20, pulando de 2 em 2.

# %%
# escreva seu código aqui

# %% [markdown]
# # Regressiva com mensagem
# Imprima os números de 15 até 1 e ao final mostre: "Lançamento encerrado".

# %%
# escreva seu código aqui

# %% [markdown]
# # Soma dos pares
# Calcule e mostre a soma dos números pares de 1 até 20.

# %%
# escreva seu código aqui

# %% [markdown]
# # Tabuada inversa
# Peça um número e mostre sua tabuada de 10 até 1.

# %%
# escreva seu código aqui

# %% [markdown]
# # Múltiplos de 3
# Imprima os múltiplos de 3 entre 1 e 30.

# %%
# escreva seu código aqui

# %% [markdown]
# # Contagem entre dois valores
# Peça dois números e mostre todos os valores entre eles.

# %%
# escreva seu código aqui

# %% [markdown]
# # Soma de intervalo
# Peça dois números e calcule a soma entre eles.

# %%
# escreva seu código aqui

# %% [markdown]
# # Repetir palavra
# Peça uma palavra e um número e repita a palavra.

# %%
# escreva seu código aqui

# %% [markdown]
# # Validação de número positivo
# Peça números até que seja digitado um valor positivo.

# %%
# escreva seu código aqui

# %% [markdown]
# # Dobro de 6 valores
# Peça 6 números e mostre o dobro de cada um.

# %%
# escreva seu código aqui

# %% [markdown]
# # Menor número
# Peça 5 números e mostre o menor.

# %%
# escreva seu código aqui

# %% [markdown]
# # Média de positivos
# Peça 6 números e calcule a média dos positivos.

# %%
# escreva seu código aqui

# %% [markdown]
# # Contar maiores que 10
# Peça 8 números e conte quantos são maiores que 10.

# %%
# escreva seu código aqui

# %% [markdown]
# # Menu com repetição
# Crie um menu até escolher sair.

# %%
# escreva seu código aqui

# %% [markdown]
# # Soma até negativo
# Some números até digitar negativo.

# %%
# escreva seu código aqui

# %% [markdown]
# # Contar pares e ímpares
# Peça 10 números e classifique.

# %%
# escreva seu código aqui

# %% [markdown]
# # Contar repetição
# Peça 7 números e conte quantas vezes aparece um valor.

# %%
# escreva seu código aqui

# %% [markdown]
# # Cofrinho
# Peça valores até digitar 0 e mostre total e quantidade.

# %%
# escreva seu código aqui

# %% [markdown]
# # Padrão numérico
# Mostre:
#
# 1
# 12
# 123
# 1234
# 12345

# %%
# escreva seu código aqui

# %% [markdown]
# # Jogo do número secreto
# Peça números até acertar o valor secreto.

# %%
# escreva seu código aqui
