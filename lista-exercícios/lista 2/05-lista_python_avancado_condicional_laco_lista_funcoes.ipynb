# %% [markdown]
# \section*{Lista de Exercícios — Python Avançado}
#
# **(Estrutura condicional + Laço + Lista + Funções)**
#
# **Regras**
#
# - Use **funções obrigatoriamente**
# - Utilize listas sempre que fizer sentido
# - Separe a lógica em partes
# - Evite usar funções prontas como `sort()`, `max()`, `min()`, salvo se o professor permitir
# - Mostre os resultados com `print()` quando necessário

# %% [markdown]
# # Sistema de notas com análise completa
# Crie uma função que receba uma lista de notas e retorne:
#
# - média
# - maior nota
# - menor nota
# - quantidade de aprovados (nota ≥ 6)

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Filtro inteligente de números
# Crie uma função que receba uma lista e retorne outra contendo apenas números:
#
# - pares
# - maiores que 10

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Verificador de lista crescente
# Crie uma função que verifica se uma lista está:
#
# - crescente
# - decrescente
# - desordenada

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Remoção de duplicados mantendo ordem
# Crie uma função que remove valores repetidos de uma lista sem perder a ordem original.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Frequência de elementos
# Crie uma função que recebe uma lista e retorna quantas vezes cada elemento aparece.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Simulador de caixa eletrônico
# Crie uma função que receba um valor e retorne a quantidade mínima de notas de:
#
# - 100
# - 50
# - 20
# - 10

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Validador de senha avançado
# Crie uma função que valida uma senha com as regras:
#
# - mínimo 8 caracteres
# - pelo menos 1 número
# - pelo menos 1 letra maiúscula
# - pelo menos 1 caractere especial

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Soma de diagonais (matriz)
# Crie uma função que recebe uma matriz (lista de listas) e retorna a soma da diagonal principal.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Rotação de lista
# Crie uma função que rotaciona uma lista N posições para a direita.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Interseção de listas
# Crie uma função que retorna os elementos comuns entre duas listas, sem repetição.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Simulação de votação
# Crie um sistema com:
#
# - lista de votos
# - função que conta votos
# - função que retorna o vencedor

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Ordenação manual (Bubble Sort)
# Implemente uma função de ordenação sem usar `sort()`.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Identificação de números primos em lista
# Crie uma função que retorna apenas os números primos de uma lista.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Agrupamento por faixa
# Dada uma lista de idades, crie uma função que retorne:
#
# - crianças (0–12)
# - jovens (13–17)
# - adultos (18+)

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Verificação de palíndromo
# Crie uma função que verifica se uma palavra é igual ao contrário.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Compactação de lista
# Crie uma função que transforma:
#
# ```python
# [1,1,1,2,2,3]
# ```
#
# em:
#
# ```python
# [(1,3), (2,2), (3,1)]
# ```

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Simulação de estoque
# Crie funções para:
#
# - adicionar produto
# - remover produto
# - consultar estoque

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Sequência de Fibonacci
# Crie uma função que retorna os N primeiros termos da sequência de Fibonacci.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Análise de números digitados
# Leia números até digitar 0 e retorne:
#
# - média
# - quantidade
# - maior
# - menor

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Sistema simples de login
# Crie um sistema com:
#
# - lista de usuários e senhas
# - função que valida login
# - máximo de 3 tentativas

# %%
# escreva sua resposta aqui
