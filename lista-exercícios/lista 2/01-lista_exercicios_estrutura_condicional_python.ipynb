# %% [markdown]
# \section*{Lista de Exercícios — Estrutura Condicional em Python}
#
# **Regras**
#
# - Resolva cada exercício usando apenas `if`, `elif` e `else`.
# - Não crie funções com `def`.
# - Você pode usar variáveis já definidas no código ou `input()` .
# - Em cada exercício, mostre o resultado usando `print()`.

# %% [markdown]
# # Temperatura do dia
#
# Crie um programa que receba uma temperatura e mostre:
#
# - `"frio"` se for menor que 18
# - `"agradável"` se estiver entre 18 e 27
# - `"quente"` se for maior que 27
#
# **Exemplo de variável:**
# ```python
# temperatura = 22
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Resultado escolar
#
# Crie um programa que receba uma nota e mostre:
#
# - `"reprovado"` se a nota for menor que 6
# - `"aprovado"` se a nota for de 6 até 10
# - `"nota inválida"` caso seja menor que 0 ou maior que 10
#
# **Exemplo:**
# ```python
# nota = 7.5
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Número múltiplo de 5
#
# Crie um programa que receba um número inteiro e mostre:
#
# - `"múltiplo de 5"` se o número for divisível por 5
# - `"não é múltiplo de 5"` caso contrário
#
# **Exemplo:**
# ```python
# n = 25
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Comparação entre duas idades
#
# Crie um programa que receba duas idades e mostre:
#
# - `"primeira maior"` se a primeira idade for maior
# - `"segunda maior"` se a segunda idade for maior
# - `"mesma idade"` se forem iguais
#
# **Exemplo:**
# ```python
# idade1 = 20
# idade2 = 18
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Situação do saldo
#
# Crie um programa que receba um valor de saldo e mostre:
#
# - `"saldo positivo"` se for maior que 0
# - `"saldo zerado"` se for igual a 0
# - `"saldo negativo"` se for menor que 0
#
# **Exemplo:**
# ```python
# saldo = -50
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Faixa de altura
#
# Crie um programa que receba uma altura em metros e mostre:
#
# - `"baixa"` se for menor que 1.60
# - `"média"` se estiver entre 1.60 e 1.80
# - `"alta"` se for maior que 1.80
#
# **Exemplo:**
# ```python
# altura = 1.72
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Pode entrar no brinquedo?
#
# Crie um programa que receba a idade de uma pessoa e mostre:
#
# - `"entrada permitida"` se tiver 12 anos ou mais
# - `"entrada não permitida"` caso contrário
#
# **Exemplo:**
# ```python
# idade = 10
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Situação do produto em estoque
#
# Crie um programa que receba a quantidade de um produto e mostre:
#
# - `"estoque vazio"` se a quantidade for 0
# - `"estoque baixo"` se a quantidade estiver entre 1 e 5
# - `"estoque ok"` se for maior que 5
#
# **Exemplo:**
# ```python
# quantidade = 3
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Menor de três valores
#
# Crie um programa que receba três números e mostre qual é o menor deles.
#
# **Exemplo:**
# ```python
# a = 8
# b = 3
# c = 5
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Classificação de senha
#
# Crie um programa que receba o tamanho de uma senha e mostre:
#
# - `"senha fraca"` se tiver menos de 6 caracteres
# - `"senha média"` se tiver de 6 a 10 caracteres
# - `"senha forte"` se tiver mais de 10 caracteres
#
# **Exemplo:**
# ```python
# tamanho = 9
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Liberação de cadastro
#
# Crie um programa que receba:
#
# - idade
# - se possui documento (`True` ou `False`)
#
# Mostre:
#
# - `"cadastro liberado"` se a pessoa tiver 18 anos ou mais **e** possuir documento
# - `"cadastro bloqueado"` caso contrário
#
# **Exemplo:**
# ```python
# idade = 19
# possui_documento = True
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Atualização de recorde
#
# Crie um programa que receba:
#
# - recorde atual
# - nova pontuação
#
# Mostre:
#
# - `"novo recorde"` se a nova pontuação for maior que o recorde atual
# - `"recorde mantido"` caso contrário
#
# **Exemplo:**
# ```python
# recorde = 120
# pontuacao = 135
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Verificação de lados
#
# Crie um programa que receba dois valores e mostre:
#
# - `"equilíbrio"` se a diferença entre eles for menor ou igual a 2
# - `"desequilíbrio"` caso contrário
#
# **Exemplo:**
# ```python
# lado1 = 10
# lado2 = 12
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Nível de consumo
#
# Crie um programa que receba um valor de consumo e mostre:
#
# - `"baixo"` se for menor que 50
# - `"moderado"` se estiver entre 50 e 150
# - `"alto"` se for maior que 150
#
# **Exemplo:**
# ```python
# consumo = 88
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Conferência de códigos
#
# Crie um programa que receba dois códigos numéricos e mostre:
#
# - `"códigos iguais"` se os dois forem iguais
# - `"códigos diferentes"` caso contrário
#
# **Exemplo:**
# ```python
# codigo1 = 123
# codigo2 = 456
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Turno do dia
#
# Crie um programa que receba uma hora inteira de 0 a 23 e mostre:
#
# - `"manhã"` se estiver entre 6 e 11
# - `"tarde"` se estiver entre 12 e 17
# - `"noite"` se estiver entre 18 e 23
# - `"madrugada"` se estiver entre 0 e 5
#
# **Exemplo:**
# ```python
# hora = 14
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Desempenho do aluno
#
# Crie um programa que receba duas notas e calcule a média. Depois mostre:
#
# - `"desempenho baixo"` se a média for menor que 5
# - `"desempenho regular"` se a média estiver entre 5 e 7.9
# - `"desempenho alto"` se a média for 8 ou mais
#
# **Exemplo:**
# ```python
# n1 = 6
# n2 = 8
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Permissão de acesso ao laboratório
#
# Crie um programa que receba:
#
# - se está matriculado (`True` ou `False`)
# - se está com uniforme (`True` ou `False`)
#
# Mostre:
#
# - `"acesso liberado"` se estiver matriculado **e** com uniforme
# - `"acesso negado"` caso contrário
#
# **Exemplo:**
# ```python
# matriculado = True
# uniforme = False
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Classificação de velocidade
#
# Crie um programa que receba a velocidade de um veículo e mostre:
#
# - `"velocidade baixa"` se for menor que 40
# - `"velocidade permitida"` se estiver entre 40 e 80
# - `"velocidade alta"` se for maior que 80
#
# **Exemplo:**
# ```python
# velocidade = 92
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui

# %% [markdown]
# # Situação de pagamento
#
# Crie um programa que receba um valor pago e um valor da compra e mostre:
#
# - `"pagamento insuficiente"` se o valor pago for menor que a compra
# - `"pagamento exato"` se forem iguais
# - `"troco disponível"` se o valor pago for maior
#
# **Exemplo:**
# ```python
# valor_pago = 100
# valor_compra = 75
# ```
#
# ```python
# # Escreva sua solução aqui
# ```

# %%
# Resolva aqui
