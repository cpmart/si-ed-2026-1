# %% [markdown]
# \section*{Lista de Exercícios — Listas em Python}
#
# **Regras**
#
# - Resolva usando listas, `for`, `while`, `if` e comandos básicos da linguagem.
# - Não utilize `def`.
# - Sempre que possível, mostre os resultados com `print()`.
# - Tente resolver primeiro sem usar funções prontas como `sum()`, `max()`, `min()` ou `sort()`.

# %% [markdown]
# # Exibir elementos com índice
# Crie uma lista com 6 números inteiros e mostre cada elemento junto com sua posição.
#
# **Exemplo de saída:**
# ```python
# Posição 0: 12
# Posição 1: 7
# ...
# ```

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Ler e armazenar 7 valores
# Peça ao usuário 7 números inteiros e armazene em uma lista. Depois, mostre a lista completa na mesma linha.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Mostrar apenas posições pares
# Dada uma lista com 8 números, mostre apenas os elementos que estão em posições pares (`0, 2, 4, 6`).

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Soma dos elementos negativos
# Peça ao usuário 6 números e armazene em uma lista. Depois, calcule e mostre a soma apenas dos valores negativos.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Criar lista com quadrados
# Dada uma lista:
#
# ```python
# [2, 4, 6, 8, 10]
# ```
#
# Crie outra lista contendo o quadrado de cada valor.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Separar positivos e negativos
# Peça 8 números ao usuário e armazene em uma lista. Depois, crie:
#
# - uma lista com os valores positivos
# - uma lista com os valores negativos
#
# Mostre as duas listas.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Contar ocorrências de um valor
# Peça 10 números ao usuário e armazene em uma lista. Depois, peça mais um número e informe quantas vezes ele aparece na lista.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Encontrar a posição do maior valor
# Dada uma lista com 7 números, encontre:
#
# - o maior valor
# - a posição em que ele aparece
#
# Tente resolver sem usar `max()`.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Média dos elementos da lista
# Peça ao usuário 5 números, armazene em uma lista e calcule a média dos valores.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Lista filtrada por limite
# Peça 8 números ao usuário e depois peça um valor limite. Crie uma nova lista contendo apenas os números maiores que esse limite.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Substituir valores negativos por zero
# Peça 6 números ao usuário e armazene em uma lista. Depois, altere a própria lista para que todo valor negativo vire `0`.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Comparar duas listas
# Crie duas listas com 5 números cada. Verifique se elas são exatamente iguais, elemento por elemento, e mostre:
#
# - `"listas iguais"`
# - `"listas diferentes"`

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Intercalar duas listas
# Crie duas listas com 4 elementos cada. Depois, monte uma terceira lista intercalando os elementos.
#
# **Exemplo:**
# ```python
# A = [1, 2, 3, 4]
# B = [10, 20, 30, 40]
# C = [1, 10, 2, 20, 3, 30, 4, 40]
# ```

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Remover um valor específico
# Peça 8 números ao usuário e armazene em uma lista. Depois, peça um valor X e crie uma nova lista sem as ocorrências de X.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Inverter manualmente
# Peça 6 números ao usuário e armazene em uma lista. Depois, crie outra lista com os elementos em ordem inversa, mas sem usar `reverse()`.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Verificar ordem crescente
# Peça 5 números ao usuário e armazene em uma lista. Verifique se a lista está em ordem crescente.
#
# **Exemplo:**
# ```python
# [2, 4, 7, 9, 10] -> crescente
# [2, 5, 3, 8, 9] -> não crescente
# ```

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Somar listas posição por posição
# Crie duas listas com 5 números cada. Depois, crie uma terceira lista em que cada posição seja a soma dos elementos correspondentes.
#
# **Exemplo:**
# ```python
# A = [1, 2, 3]
# B = [4, 5, 6]
# C = [5, 7, 9]
# ```

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Mostrar elementos repetidos
# Peça 10 números ao usuário e armazene em uma lista. Depois, mostre quais valores aparecem repetidos.
#
# **Observação:** mostre cada valor repetido apenas uma vez.

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Rotacionar a lista
# Dada uma lista com 6 elementos, mova o primeiro elemento para o final.
#
# **Exemplo:**
# ```python
# [3, 7, 9, 1, 5, 8]
# ```
#
# deve se tornar:
#
# ```python
# [7, 9, 1, 5, 8, 3]
# ```

# %%
# escreva sua resposta aqui

# %% [markdown]
# # Montar lista sem duplicatas durante a leitura
# Peça 8 números ao usuário. Armazene em uma lista apenas os valores que ainda não apareceram.
#
# **Exemplo:**
# Se o usuário digitar:
#
# ```python
# 2, 5, 2, 8, 5, 1, 8, 3
# ```
# a lista final deve ser:
#
# ```python
# [2, 5, 8, 1, 3]
# ```

# %%
# escreva sua resposta aqui
