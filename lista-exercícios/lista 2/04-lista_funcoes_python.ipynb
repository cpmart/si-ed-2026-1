# %% [markdown]
# \section*{Lista de Exercícios — Funções em Python}
#
# **Regras**
#
# - Todos os exercícios devem usar funções (`def`)
# - Separe entrada, processamento e saída quando possível
# - Utilize `return` quando necessário

# %% [markdown]
# # Função que mostra mensagem
# Crie uma função chamada `mensagem()` que exibe:
# Aprendendo funções em Python!

# %%
def mensagem():
    print("Aprendendo funções em Python!")

mensagem()
# Out:
# Aprendendo funções em Python!

# %% [markdown]
# # Função com parâmetro
# Crie uma função `saudacao(nome)` que recebe um nome e mostra:
#
# Olá, João!

# %%
def saudacao(nome):
    print(f"Olá, {nome}!")

meuNome = "Cristiano"
saudacao(meuNome)
# Out:
# Olá, Cristiano!

# %% [markdown]
# # Função que retorna o dobro
# Crie uma função `dobro(n)` que retorna o dobro de um número.

# %%
def dobro(valor):
    return valor*2
numero = int(input("Digite um valor:"))
print(dobro(numero))
# Out:
# 50

# %% [markdown]
# # Função que verifica positivo
# Crie uma função `eh_positivo(n)` que retorna True se positivo, senão False.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função maior de dois números
# Crie uma função `maior(a, b)` que retorna o maior valor.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função para calcular média
# Crie uma função `media(a, b)` que retorna a média de dois números.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que verifica par
# Crie uma função `eh_par(n)` que retorna True se o número for par.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que soma lista
# Crie uma função `soma_lista(lista)` que retorna a soma dos elementos.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que conta positivos
# Crie uma função `contar_positivos(lista)`.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que encontra o maior
# Crie uma função `maior_lista(lista)` sem usar max().

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que filtra pares
# Crie uma função `filtrar_pares(lista)`.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que inverte lista
# Crie uma função `inverter(lista)` sem usar reverse().

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que conta ocorrências
# Crie uma função `contar(lista, valor)`.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que verifica crescente
# Crie uma função `crescente(lista)`.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que remove duplicados
# Crie uma função `sem_duplicados(lista)`.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função que soma listas
# Crie uma função `somar_listas(a, b)`.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função fatorial
# Crie uma função `fatorial(n)`.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função número primo
# Crie uma função `eh_primo(n)`.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função sequência
# Crie uma função `sequencia(n)` que retorna lista de 1 até n.

# %%
# escreva seu código aqui

# %% [markdown]
# # Função valida senha
# Crie uma função `senha_valida(senha)` com regras:
#
# - mínimo 8 caracteres
# - pelo menos um número

# %%
# escreva seu código aqui
